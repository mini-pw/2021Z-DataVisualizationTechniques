# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

excel_df = pd.read_excel ("Project.xlsx")
excel_df["Tygodniowa liczba przebadanych próbek w woj. 09-16.11"]
#sns.pairplot(excel_df, hue="Województwo")
excel_df.head
# Out:
# <bound method NDFrame.head of             Województwo  \
# 0               Śląskie
# 1           Mazowieckie
# 2           Małopolskie
# 3         Wielkopolskie
# 4          Dolnośląskie
# 5               Łódzkie
# 6    Kujawsko-Pomorskie
# 7          Podkarpackie
# 8             Pomorskie
# 9             Lubelskie
# 10   Zachodniopomorskie
# 11       Świętokrzyskie
# 12             Opolskie
# 13            Podlaskie
# 14  Warmińsko-Mazurskie
# 15             Lubuskie
#
#     Tygodniowa liczba przebadanych próbek w woj. 09-16.11  \
# 0                                               52739
# 1                                               56417
# 2                                               15780
# 3                                               38233
# 4                                               36051
# 5                                               24608
# 6                                               21751
# 7                                                7302
# ...

# %%
fig, ax = plt.subplots()
a1=plt.scatter(excel_df["wykres1x"][0],excel_df["wykres1y"][0],marker="o",color="orangered",s=50)
a2=plt.scatter(excel_df["wykres1x"][1],excel_df["wykres1y"][1],marker="o",color="yellowgreen",s=50)
a3=plt.scatter(excel_df["wykres1x"][2],excel_df["wykres1y"][2],marker="o",color="#a8a8a8",s=50)
a4=plt.scatter(excel_df["wykres1x"][3],excel_df["wykres1y"][3],marker="o",color="#a8a8a8",s=50)
b1=plt.scatter(excel_df["wykres1x"][4],excel_df["wykres1y"][4],marker="o",color="#a8a8a8",s=50)
b2=plt.scatter(excel_df["wykres1x"][5],excel_df["wykres1y"][5],marker="o",color="teal",s=50)
b3=plt.scatter(excel_df["wykres1x"][6],excel_df["wykres1y"][6],marker="o",color="green",s=50)
b4=plt.scatter(excel_df["wykres1x"][7],excel_df["wykres1y"][7],marker="o",color="orange",s=50)
c1=plt.scatter(excel_df["wykres1x"][8],excel_df["wykres1y"][8],marker="o",color="#a8a8a8",s=50)
c2=plt.scatter(excel_df["wykres1x"][9],excel_df["wykres1y"][9],marker="o",color="#a8a8a8",s=50)
c3=plt.scatter(excel_df["wykres1x"][10],excel_df["wykres1y"][10],marker="o",color="#a8a8a8",s=50)
c4=plt.scatter(excel_df["wykres1x"][11],excel_df["wykres1y"][11],marker="o",color="#a8a8a8",s=50)
d1=plt.scatter(excel_df["wykres1x"][12],excel_df["wykres1y"][12],marker="o",color="crimson",s=50)
d2=plt.scatter(excel_df["wykres1x"][13],excel_df["wykres1y"][13],marker="o",color="#a8a8a8",s=50)
d3=plt.scatter(excel_df["wykres1x"][14],excel_df["wykres1y"][14],marker="o",color="#a8a8a8",s=50)
d4=plt.scatter(excel_df["wykres1x"][15],excel_df["wykres1y"][15],marker="o",color="#a8a8a8",s=50)
plt.legend((d1,a1,b4,b3,b2,a2,a3),("Opolskie","Śląskie","Podkarpackie","Kujawsko-Pomorskie","Łódzkie","Mazowieckie","Pozostałe"),bbox_to_anchor=(1, 1), loc='upper left',facecolor='white', framealpha=0)
plt.xlabel("Liczba osób/łóżko",size=13)
plt.ylabel("Liczba osób/repirator",size=13)
plt.title("Przygotowanie Szpitali",size=15)


ax.annotate("Śląskie", (excel_df["wykres1x"][0]-40, excel_df["wykres1y"][0]+1100))
plt.arrow(excel_df["wykres1x"][0],excel_df["wykres1y"][0],0,1000, 
         shape='full', color='k', length_includes_head=True, 
         zorder=0, head_length=3., head_width=1.5)

ax.annotate("Mazowieckie", (excel_df["wykres1x"][1]-68, excel_df["wykres1y"][1]+1100))
plt.arrow(excel_df["wykres1x"][1],excel_df["wykres1y"][1],0,1000, 
         shape='full', color='k', length_includes_head=True, 
         zorder=0, head_length=3., head_width=1.5)

ax.annotate("Łódzkie", (excel_df["wykres1x"][5]-40, excel_df["wykres1y"][5]-1000))
plt.arrow(excel_df["wykres1x"][5],excel_df["wykres1y"][5],0,-600, 
         shape='full', color='k', length_includes_head=True, 
         zorder=0, head_length=3., head_width=1.5)

ax.annotate("Kujawsko-Pomorskie", (excel_df["wykres1x"][6]+20, excel_df["wykres1y"][6]+1100))
plt.arrow(excel_df["wykres1x"][6],excel_df["wykres1y"][6],130,900, 
         shape='full', color='k', length_includes_head=True, 
         zorder=0, head_length=3., head_width=1.5)

ax.annotate("Podkarpackie", (excel_df["wykres1x"][7]-150, excel_df["wykres1y"][7]+1100))
plt.arrow(excel_df["wykres1x"][7],excel_df["wykres1y"][7],-60,900, 
         shape='full', color='k', length_includes_head=True, 
         zorder=0, head_length=3., head_width=1.5)

ax.annotate("Opolskie", (excel_df["wykres1x"][12]-40, excel_df["wykres1y"][12]+1100))
plt.arrow(excel_df["wykres1x"][12],excel_df["wykres1y"][12],0,900, 
         shape='full', color='k', length_includes_head=True, 
         zorder=0, head_length=3., head_width=1.5)
ax.patch.set_alpha(0)
plt.xticks(fontsize=13)
plt.yticks(fontsize=13)
# Out:
# (array([ 8000., 10000., 12000., 14000., 16000., 18000., 20000., 22000.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
fig, ax = plt.subplots()
a1=plt.scatter(excel_df["wykres3x"][0],excel_df["wykres3y"][0],marker="o",color="orangered",s=50)
a2=plt.scatter(excel_df["wykres3x"][1],excel_df["wykres3y"][1],marker="o",color="yellowgreen",s=50)
a3=plt.scatter(excel_df["wykres3x"][2],excel_df["wykres3y"][2],marker="o",color="#a8a8a8",s=50)
a4=plt.scatter(excel_df["wykres3x"][3],excel_df["wykres3y"][3],marker="o",color="#a8a8a8",s=50)
b1=plt.scatter(excel_df["wykres3x"][4],excel_df["wykres3y"][4],marker="o",color="#a8a8a8",s=50)
b2=plt.scatter(excel_df["wykres3x"][5],excel_df["wykres3y"][5],marker="o",color="teal",s=50)
b3=plt.scatter(excel_df["wykres3x"][6],excel_df["wykres3y"][6],marker="o",color="green",s=50)
b4=plt.scatter(excel_df["wykres3x"][7],excel_df["wykres3y"][7],marker="o",color="orange",s=50)
c1=plt.scatter(excel_df["wykres3x"][8],excel_df["wykres3y"][8],marker="o",color="#a8a8a8",s=50)
c2=plt.scatter(excel_df["wykres3x"][9],excel_df["wykres3y"][9],marker="o",color="#a8a8a8",s=50)
c3=plt.scatter(excel_df["wykres3x"][10],excel_df["wykres3y"][10],marker="o",color="#a8a8a8",s=50)
c4=plt.scatter(excel_df["wykres3x"][11],excel_df["wykres3y"][11],marker="o",color="#a8a8a8",s=50)
d1=plt.scatter(excel_df["wykres3x"][12],excel_df["wykres3y"][12],marker="o",color="crimson",s=50)
d2=plt.scatter(excel_df["wykres3x"][13],excel_df["wykres3y"][13],marker="o",color="#a8a8a8",s=50)
d3=plt.scatter(excel_df["wykres3x"][14],excel_df["wykres3y"][14],marker="o",color="#a8a8a8",s=50)
d4=plt.scatter(excel_df["wykres3x"][15],excel_df["wykres3y"][15],marker="o",color="#a8a8a8",s=50)

plt.xlabel("Wyzdrowienia/wyniki pozytywne",size=13)
plt.ylabel("Zgony/wyniki pozytywne",size=13)
plt.title("Zakończenie Choroby",size=15)

ax.annotate("Śląskie", (excel_df["wykres3x"][0]-0.02, excel_df["wykres3y"][0]+0.003))
plt.arrow(excel_df["wykres3x"][0],excel_df["wykres3y"][0],0,0.0027, 
         shape='full', color='k', length_includes_head=True, 
         zorder=0, head_length=0, head_width=0)

ax.annotate("Mazowieckie", (excel_df["wykres3x"][1]-0.053, excel_df["wykres3y"][1]-0.005))
plt.arrow(excel_df["wykres3x"][1],excel_df["wykres3y"][1],0,-0.0035, 
         shape='full', color='k', length_includes_head=True, 
         zorder=0, head_length=0, head_width=0)

ax.annotate("Łódzkie", (excel_df["wykres3x"][5]-0.02, excel_df["wykres3y"][5]+0.003))
plt.arrow(excel_df["wykres3x"][5],excel_df["wykres3y"][5],0,0.0027, 
         shape='full', color='k', length_includes_head=True, 
         zorder=0, head_length=0, head_width=0)

ax.annotate("Kujawsko-Pomorskie", (excel_df["wykres3x"][6]-0.015, excel_df["wykres3y"][6]-0.004))
plt.arrow(excel_df["wykres3x"][6],excel_df["wykres3y"][6],0,-0.0025, 
         shape='full', color='k', length_includes_head=True, 
         zorder=0, head_length=0, head_width=0)

ax.annotate("Podkarpackie", (excel_df["wykres3x"][7]-0.03, excel_df["wykres3y"][7]+0.003))
plt.arrow(excel_df["wykres3x"][7],excel_df["wykres3y"][7],0,0.0027, 
         shape='full', color='k', length_includes_head=True, 
         zorder=0, head_length=0, head_width=0)

ax.annotate("Opolskie", (excel_df["wykres3x"][12]-0.02, excel_df["wykres3y"][12]+0.003))
plt.arrow(excel_df["wykres3x"][12],excel_df["wykres3y"][12],0,0.0027, 
         shape='full', color='k', length_includes_head=True, 
         zorder=0, head_length=0, head_width=0)
ax.patch.set_alpha(0)
plt.xticks(fontsize=13)
plt.yticks(fontsize=13)
# Out:
# (array([-0.005,  0.   ,  0.005,  0.01 ,  0.015,  0.02 ,  0.025,  0.03 ,
#          0.035]),
#  <a list of 9 Text yticklabel objects>)

# %%
fig, ax = plt.subplots()
a1=plt.scatter(excel_df["% zajęte łóżka"][0],excel_df["% zajęte repiratorów"][0],marker="o",color="orangered",s=50)
a2=plt.scatter(excel_df["% zajęte łóżka"][1],excel_df["% zajęte repiratorów"][1],marker="o",color="yellowgreen",s=50)
a3=plt.scatter(excel_df["% zajęte łóżka"][2],excel_df["% zajęte repiratorów"][2],marker="o",color="#a8a8a8",s=50)
a4=plt.scatter(excel_df["% zajęte łóżka"][3],excel_df["% zajęte repiratorów"][3],marker="o",color="#a8a8a8",s=50)
b1=plt.scatter(excel_df["% zajęte łóżka"][4],excel_df["% zajęte repiratorów"][4],marker="o",color="#a8a8a8",s=50)
b2=plt.scatter(excel_df["% zajęte łóżka"][5],excel_df["% zajęte repiratorów"][5],marker="o",color="teal",s=50)
b3=plt.scatter(excel_df["% zajęte łóżka"][6],excel_df["% zajęte repiratorów"][6],marker="o",color="green",s=50)
b4=plt.scatter(excel_df["% zajęte łóżka"][7],excel_df["% zajęte repiratorów"][7],marker="o",color="orange",s=50)
c1=plt.scatter(excel_df["% zajęte łóżka"][8],excel_df["% zajęte repiratorów"][8],marker="o",color="#a8a8a8",s=50)
c2=plt.scatter(excel_df["% zajęte łóżka"][9],excel_df["% zajęte repiratorów"][9],marker="o",color="#a8a8a8",s=50)
c3=plt.scatter(excel_df["% zajęte łóżka"][10],excel_df["% zajęte repiratorów"][10],marker="o",color="#a8a8a8",s=50)
c4=plt.scatter(excel_df["% zajęte łóżka"][11],excel_df["% zajęte repiratorów"][11],marker="o",color="#a8a8a8",s=50)
d1=plt.scatter(excel_df["% zajęte łóżka"][12],excel_df["% zajęte repiratorów"][12],marker="o",color="crimson",s=50)
d2=plt.scatter(excel_df["% zajęte łóżka"][13],excel_df["% zajęte repiratorów"][13],marker="o",color="#a8a8a8",s=50)
d3=plt.scatter(excel_df["% zajęte łóżka"][14],excel_df["% zajęte repiratorów"][14],marker="o",color="#a8a8a8",s=50)
d4=plt.scatter(excel_df["% zajęte łóżka"][15],excel_df["% zajęte repiratorów"][15],marker="o",color="#a8a8a8",s=50)
plt.xlabel("Procentowe zajęcie łóżek",size=13)
plt.ylabel("Procentowe zajęcie respiratorów",size=13)
plt.title("Rzeczywista sytuacja w szpitalach",size=15)

ax.annotate("Śląskie", (excel_df["% zajęte łóżka"][0]-0.01, excel_df["% zajęte repiratorów"][0]+0.03))
plt.arrow(excel_df["% zajęte łóżka"][0],excel_df["% zajęte repiratorów"][0],0,0.024, 
         shape='full', color='k', length_includes_head=True, 
         zorder=0, head_length=0, head_width=0)

ax.annotate("Mazowieckie", (excel_df["% zajęte łóżka"][1]-0.016, excel_df["% zajęte repiratorów"][1]-0.06))
plt.arrow(excel_df["% zajęte łóżka"][1],excel_df["% zajęte repiratorów"][1],0,-0.040, 
         shape='full', color='k', length_includes_head=True, 
         zorder=0, head_length=0, head_width=0)

ax.annotate("Łódzkie", (excel_df["% zajęte łóżka"][5]-0.01, excel_df["% zajęte repiratorów"][5]+0.03))
plt.arrow(excel_df["% zajęte łóżka"][5],excel_df["% zajęte repiratorów"][5],0,0.024, 
         shape='full', color='k', length_includes_head=True, 
         zorder=0, head_length=0, head_width=0)

ax.annotate("Kujawsko-Pomorskie", (excel_df["% zajęte łóżka"][6]-0.007, excel_df["% zajęte repiratorów"][6]+0.03))
plt.arrow(excel_df["% zajęte łóżka"][6],excel_df["% zajęte repiratorów"][6],0.017,0.024, 
         shape='full', color='k', length_includes_head=True, 
         zorder=0, head_length=0, head_width=0)

ax.annotate("Podkarpackie", (excel_df["% zajęte łóżka"][7]-0.017, excel_df["% zajęte repiratorów"][7]+0.03))
plt.arrow(excel_df["% zajęte łóżka"][7],excel_df["% zajęte repiratorów"][7],0,0.024, 
         shape='full', color='k', length_includes_head=True, 
         zorder=0, head_length=0, head_width=0)

ax.annotate("Opolskie", (excel_df["% zajęte łóżka"][12]-0.01, excel_df["% zajęte repiratorów"][12]+0.04))
plt.arrow(excel_df["% zajęte łóżka"][12],excel_df["% zajęte repiratorów"][12],0,0.034, 
         shape='full', color='k', length_includes_head=True, 
         zorder=0, head_length=0, head_width=0)
ax.patch.set_alpha(0)

scale_x = 100
ticks_x = ticker.FuncFormatter(lambda x, pos: f'{str(int(round(x*scale_x,1)))+"%"}')
ax.xaxis.set_major_formatter(ticks_x)
scale_y = 100
ticks_y = ticker.FuncFormatter(lambda y, pos: f'{str(int(round(y*scale_y,1)))+"%"}')
ax.yaxis.set_major_formatter(ticks_y)
plt.xticks(fontsize=13)
plt.yticks(fontsize=13)
# Out:
# (array([0.45, 0.5 , 0.55, 0.6 , 0.65, 0.7 , 0.75, 0.8 , 0.85, 0.9 , 0.95]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])
