# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

excel_df = pd.read_excel (r"C:\Users\Admin_\Documents\Jupyter\Project2.xlsx")
excel_df["Tygodniowa liczba przebadanych próbek w woj. 09-16.11"]
#sns.pairplot(excel_df, hue="Województwo")
excel_df.head
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-a031e243d6db> in <module>
#       4 import matplotlib.pyplot as plt
#       5
# ----> 6 excel_df = pd.read_excel (r"C:\Users\Admin_\Documents\Jupyter\Project2.xlsx")
#       7 excel_df["Tygodniowa liczba przebadanych próbek w woj. 09-16.11"]
#       8 #sns.pairplot(excel_df, hue="Województwo")
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     294                 )
#     295                 warnings.warn(msg, FutureWarning, stacklevel=stacklevel)
# --> 296             return func(*args, **kwargs)
#     297
#     298         return wrapper
#
# ...

# %%
a1=plt.scatter(excel_df["wykres1x"][0],excel_df["wykres1y"][0],marker="*",color="g",s=50)
a2=plt.scatter(excel_df["wykres1x"][1],excel_df["wykres1y"][1],marker="*",color="b",s=50)
a3=plt.scatter(excel_df["wykres1x"][2],excel_df["wykres1y"][2],marker="*",color="r",s=50)
a4=plt.scatter(excel_df["wykres1x"][3],excel_df["wykres1y"][3],marker="*",color="m",s=50)
b1=plt.scatter(excel_df["wykres1x"][4],excel_df["wykres1y"][4],marker="s",color="g",s=50)
b2=plt.scatter(excel_df["wykres1x"][5],excel_df["wykres1y"][5],marker="s",color="b",s=50)
b3=plt.scatter(excel_df["wykres1x"][6],excel_df["wykres1y"][6],marker="s",color="r",s=50)
b4=plt.scatter(excel_df["wykres1x"][7],excel_df["wykres1y"][7],marker="s",color="m",s=50)
c1=plt.scatter(excel_df["wykres1x"][8],excel_df["wykres1y"][8],marker="^",color="g",s=50)
c2=plt.scatter(excel_df["wykres1x"][9],excel_df["wykres1y"][9],marker="^",color="b",s=50)
c3=plt.scatter(excel_df["wykres1x"][10],excel_df["wykres1y"][10],marker="^",color="r",s=50)
c4=plt.scatter(excel_df["wykres1x"][11],excel_df["wykres1y"][11],marker="^",color="m",s=50)
d1=plt.scatter(excel_df["wykres1x"][12],excel_df["wykres1y"][12],marker="o",color="g",s=50)
d2=plt.scatter(excel_df["wykres1x"][13],excel_df["wykres1y"][13],marker="o",color="b",s=50)
d3=plt.scatter(excel_df["wykres1x"][14],excel_df["wykres1y"][14],marker="o",color="r",s=50)
d4=plt.scatter(excel_df["wykres1x"][15],excel_df["wykres1y"][15],marker="o",color="m",s=50)
plt.legend((a1,a2,a3,a4,b1,b2,b3,b4,c1,c2,c3,c4,d1,d2,d3,d4),("Śląskie","Mazowieckie","Małopolskie","Wielkopolskie","Dolnośląskie","Łódzkie","Kujawsko-Pomorskie","Podkarpackie","Pomorskie","Lubelskie","Zachodniopomorskie","Świętokrzyskie","Opolskie","Podlaskie","Warmińsko-Mazurskie","Lubuskie"),bbox_to_anchor=(1, 1), loc='upper left')
plt.xlabel("Liczba osób/łóżko")
plt.ylabel("Liczba osób/repirator")
plt.title("Przygotowanie")
# Out:
# Text(0.5, 1.0, 'Przygotowanie')

# %%
a1=plt.scatter(excel_df["wykres3x"][0],excel_df["wykres3y"][0],marker="*",color="g",s=50)
a2=plt.scatter(excel_df["wykres3x"][1],excel_df["wykres3y"][1],marker="*",color="b",s=50)
a3=plt.scatter(excel_df["wykres3x"][2],excel_df["wykres3y"][2],marker="*",color="r",s=50)
a4=plt.scatter(excel_df["wykres3x"][3],excel_df["wykres3y"][3],marker="*",color="m",s=50)
b1=plt.scatter(excel_df["wykres3x"][4],excel_df["wykres3y"][4],marker="s",color="g",s=50)
b2=plt.scatter(excel_df["wykres3x"][5],excel_df["wykres3y"][5],marker="s",color="b",s=50)
b3=plt.scatter(excel_df["wykres3x"][6],excel_df["wykres3y"][6],marker="s",color="r",s=50)
b4=plt.scatter(excel_df["wykres3x"][7],excel_df["wykres3y"][7],marker="s",color="m",s=50)
c1=plt.scatter(excel_df["wykres3x"][8],excel_df["wykres3y"][8],marker="^",color="g",s=50)
c2=plt.scatter(excel_df["wykres3x"][9],excel_df["wykres3y"][9],marker="^",color="b",s=50)
c3=plt.scatter(excel_df["wykres3x"][10],excel_df["wykres3y"][10],marker="^",color="r",s=50)
c4=plt.scatter(excel_df["wykres3x"][11],excel_df["wykres3y"][11],marker="^",color="m",s=50)
d1=plt.scatter(excel_df["wykres3x"][12],excel_df["wykres3y"][12],marker="o",color="g",s=50)
d2=plt.scatter(excel_df["wykres3x"][13],excel_df["wykres3y"][13],marker="o",color="b",s=50)
d3=plt.scatter(excel_df["wykres3x"][14],excel_df["wykres3y"][14],marker="o",color="r",s=50)
d4=plt.scatter(excel_df["wykres3x"][15],excel_df["wykres3y"][15],marker="o",color="m",s=50)
plt.legend((a1,a2,a3,a4,b1,b2,b3,b4,c1,c2,c3,c4,d1,d2,d3,d4),("Śląskie","Mazowieckie","Małopolskie","Wielkopolskie","Dolnośląskie","Łódzkie","Kujawsko-Pomorskie","Podkarpackie","Pomorskie","Lubelskie","Zachodniopomorskie","Świętokrzyskie","Opolskie","Podlaskie","Warmińsko-Mazurskie","Lubuskie"),bbox_to_anchor=(1, 1), loc='upper left')
plt.xlabel("Wyzdrowienia/wyniki pozytywne")
plt.ylabel("Zgony/wyniki pozytywne")
plt.title("Skutek Choroby")
# Out:
# Text(0.5, 1.0, 'Skutek Choroby')

# %%
a1=plt.scatter(excel_df["% zajęte łóżka"][0],excel_df["% zajęte repiratorów"][0],marker="*",color="g",s=50)
a2=plt.scatter(excel_df["% zajęte łóżka"][1],excel_df["% zajęte repiratorów"][1],marker="*",color="b",s=50)
a3=plt.scatter(excel_df["% zajęte łóżka"][2],excel_df["% zajęte repiratorów"][2],marker="*",color="r",s=50)
a4=plt.scatter(excel_df["% zajęte łóżka"][3],excel_df["% zajęte repiratorów"][3],marker="*",color="m",s=50)
b1=plt.scatter(excel_df["% zajęte łóżka"][4],excel_df["% zajęte repiratorów"][4],marker="s",color="g",s=50)
b2=plt.scatter(excel_df["% zajęte łóżka"][5],excel_df["% zajęte repiratorów"][5],marker="s",color="b",s=50)
b3=plt.scatter(excel_df["% zajęte łóżka"][6],excel_df["% zajęte repiratorów"][6],marker="s",color="r",s=50)
b4=plt.scatter(excel_df["% zajęte łóżka"][7],excel_df["% zajęte repiratorów"][7],marker="s",color="m",s=50)
c1=plt.scatter(excel_df["% zajęte łóżka"][8],excel_df["% zajęte repiratorów"][8],marker="^",color="g",s=50)
c2=plt.scatter(excel_df["% zajęte łóżka"][9],excel_df["% zajęte repiratorów"][9],marker="^",color="b",s=50)
c3=plt.scatter(excel_df["% zajęte łóżka"][10],excel_df["% zajęte repiratorów"][10],marker="^",color="r",s=50)
c4=plt.scatter(excel_df["% zajęte łóżka"][11],excel_df["% zajęte repiratorów"][11],marker="^",color="m",s=50)
d1=plt.scatter(excel_df["% zajęte łóżka"][12],excel_df["% zajęte repiratorów"][12],marker="o",color="g",s=50)
d2=plt.scatter(excel_df["% zajęte łóżka"][13],excel_df["% zajęte repiratorów"][13],marker="o",color="b",s=50)
d3=plt.scatter(excel_df["% zajęte łóżka"][14],excel_df["% zajęte repiratorów"][14],marker="o",color="r",s=50)
d4=plt.scatter(excel_df["% zajęte łóżka"][15],excel_df["% zajęte repiratorów"][15],marker="o",color="m",s=50)
plt.legend((a1,a2,a3,a4,b1,b2,b3,b4,c1,c2,c3,c4,d1,d2,d3,d4),("Śląskie","Mazowieckie","Małopolskie","Wielkopolskie","Dolnośląskie","Łódzkie","Kujawsko-Pomorskie","Podkarpackie","Pomorskie","Lubelskie","Zachodniopomorskie","Świętokrzyskie","Opolskie","Podlaskie","Warmińsko-Mazurskie","Lubuskie"),bbox_to_anchor=(1, 1), loc='upper left')
plt.xlabel("% zajęcie łóżek")
plt.ylabel("% zajęcie respiratorów")
plt.title("Rzeczywistość")
# Out:
# Text(0.5, 1.0, 'Rzeczywistość')

# %%
a1=sns.barplot(excel_df["wykres4y"],excel_df["Województwo"]*100,dodge=False,color="b")
plt.ylabel("Województwa")
plt.xlabel("% chorych")
plt.title("Procentowa chorych")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-4cca6ad42809> in <module>
# ----> 1 a1=sns.barplot(excel_df["wykres4y"],excel_df["Województwo"]*100,dodge=False,color="b")
#       2 plt.ylabel("Województwa")
#       3 plt.xlabel("% chorych")
#       4 plt.title("Procentowa chorych")
#
# NameError: name 'excel_df' is not defined
