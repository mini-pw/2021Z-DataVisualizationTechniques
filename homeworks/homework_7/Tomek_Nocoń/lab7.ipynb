# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %% [markdown]
# *https://ctmirror.org/category/ct-viewpoints/there-are-tools-to-address-the-racial-ethnic-health-disparities-exposed-by-the-coronavirus/*

# %% [markdown]
# *https://github.com/mini-pw/2021Z-DataVisualizationTechniques/blob/master/homeworks/homework_2/Nocoń_Tomek/Zad2.pdf*

# %%
Ethnic = ["Hispanic", "American indain", "Asian", "Black", "White"]
Ethnic1 = []
Number = [1195, 408, 324, 1299, 531]
A = np.argsort(Number)[::-1]
for i in range(len(Number)):
    Ethnic1.append(Ethnic[A[i]])
Number.sort()
Number = Number[::-1]

# %%
fig, ax = plt.subplots(figsize=(15,10))

bar_plot = plt.bar(Ethnic1, Number)

def label(bars):
    for idx,rect in enumerate(bar_plot):
        height = rect.get_height()
        ax.text(rect.get_x() + rect.get_width()/2., height,
                Number[idx],
                ha='center', va='bottom', rotation=0)

autolabel(bar_plot)
plt.xlabel("Ethic")
plt.ylabel("Rate per 100,000 population")
plt.title('Race of COVID-19 cases by race/ethnic in Connecticut')
plt.show()

# %% [markdown]
# # Co zostalo poprawione?
# * dodanie konkretnych wartości co pozwala na dokładniejsze odczytanie wykresu.
# * w związku z tym, nie potrzebne jest szare tło z kratką, które miało teoretycznie pomóc w odczycie
# * wykres jest prze to schludniejszy
# * wiecej liczb na osi y, co równiej daje lepszy ogląd na wartości słupków
