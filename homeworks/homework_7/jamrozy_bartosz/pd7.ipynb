# %% [markdown]
# ## Orginał
# Poprawiam swoją, [pracę](https://github.com/mini-pw/2021Z-DataVisualizationTechniques/blob/master/homeworks/homework_2/jamrozy_bartosz/pd2.pdf)
# orginalny wykres z tvn: ![Caption for the picture.](tvn_ogrinal.jpg)

# %% [markdown]
# ## Poprawka w R:
# ![Caption for the picture.](Pd2_tvn.png)

# %% [markdown]
# ## Pytnon:
# Uznałem że warto usunąć czerwoną linie, pokazuje ona dokładnie te same dane co słupki (niepotrzebne zdublowanie).

# %%
import seaborn as sns
sns.set_style("whitegrid")
date=["1.10","2.10","3.10","4.10","5.10","6.10","7.10","8.10"]
cases=[1967,2292,2367,1934,2006,2236,3003,4280]
s=sns.barplot(x=date,y=cases,color="navy")

for idx, ax in np.ndenumerate(s):
    for p in ax.patches:
        _x = p.get_x() + p.get_width() / 2 
        _y = p.get_y() + p.get_height() + 20
        value = int(p.get_height())
        ax.text(_x, _y, value, ha="center")
        
s.set_title("Liczna nowych przypadków zakażenia koronawirusem \n w Polsce, w kolejny dniach")
# Out:
# Text(0.5, 1.0, 'Liczna nowych przypadków zakażenia koronawirusem \n w Polsce, w kolejny dniach')

# %% [markdown]
# Dodatkowo wykres jest teraz bardziej zwarty, moim zdaniem lepiej.
