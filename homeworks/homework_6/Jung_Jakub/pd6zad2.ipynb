# %%
import matplotlib.pyplot as plt

labels = ['Blue', 'Red', 'Green', 'Purple']
sizes = [15, 30, 45, 10]

plt.bar(labels, sizes, color = labels)
plt.show()

# %%
plt.pie(sizes, colors = labels, labels = labels)
plt.show()
